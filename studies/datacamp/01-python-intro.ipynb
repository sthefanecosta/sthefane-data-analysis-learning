# %% [markdown]
# # [INTRODUÇÃO AO PYTHON] - [OLÁ, PYTHON!]
# **Plataforma:** DataCamp
#
# **Data:** 2026-06-16
#
# **Status:** Em andamento | Concluído

# %%
4 + 5
# Out:
# 9

# %% [markdown]
# ## 📚 Objetivo desta aula
#  Aprender o que é Script Python e como usar o shell IPython para fazer testes e o editor de scripts Python para programar a resposta em si

# %% [markdown]
# ## 1️⃣ Conceito Teórico

# %% [markdown]
# ### O que é?
# Scripts Python são arquivos de texto com a extensão .py. É básicamente uma lista de comandos Python que são executados no shell.

# %% [markdown]
# ### Por quê aprender?
# Ajuda a memorizar e a manter os Scripts corretamente de forma interativa.

# %% [markdown]
# ## 2️⃣ Exemplos da Aula

# %%
# Hit run code to see the output!
print(5 / 8)
# Out:
# 0.625

# %%
# Adição e divisão
print(4 + 5)
print(10 / 2)
# Out:
# 9
# 5.0

# %%
# Subtração
print(10 - 5)
# Out:
# 5

# %%
# Multiplicação
print(3 * 5)
# Out:
# 15

# %% [markdown]
# # **O que aconteceu:**
# O Python retornou uma saída utilizando o comando print() mostrando o resultado de cada calculo feito.
